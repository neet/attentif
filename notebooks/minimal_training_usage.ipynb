# %%
from transformers import pipeline, BertForMaskedLM, AutoTokenizer

# %%
model = BertForMaskedLM.from_pretrained("./results/checkpoint-18750")
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
fill_mask = pipeline('fill-mask', model=model, tokenizer=tokenizer)
# Out:
# Device set to use mps:0

# %%
fill_mask("Who slammed our certain rights as bitter [MASK]?")
# Out:
# [{'score': 0.043603915721178055,
#   'token': 2015,
#   'token_str': '##s',
#   'sequence': 'who slammed our certain rights as bitters?'},
#  {'score': 0.03263738378882408,
#   'token': 2162,
#   'token_str': 'war',
#   'sequence': 'who slammed our certain rights as bitter war?'},
#  {'score': 0.025214094668626785,
#   'token': 4808,
#   'token_str': 'violence',
#   'sequence': 'who slammed our certain rights as bitter violence?'},
#  {'score': 0.022237731143832207,
#   'token': 2916,
#   'token_str': 'rights',
#   'sequence': 'who slammed our certain rights as bitter rights?'},
#  {'score': 0.010960821062326431,
#   'token': 4331,
#   'token_str': 'politics',
#   'sequence': 'who slammed our certain rights as bitter politics?'}]
