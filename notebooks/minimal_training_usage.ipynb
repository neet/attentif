# %%
from transformers import pipeline, BertForMaskedLM, AutoTokenizer

# %%
model = BertForMaskedLM.from_pretrained("../outputs/checkpoint-18750")
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
fill_mask = pipeline('fill-mask', model=model, tokenizer=tokenizer)
# Out:
# Device set to use mps:0

# %%
fill_mask("All human [MASK] are born free and equal in dignity and rights.")
# Out:
# [{'score': 0.03475303575396538,
#   'token': 2916,
#   'token_str': 'rights',
#   'sequence': 'all human rights are born free and equal in dignity and rights.'},
#  {'score': 0.02283480577170849,
#   'token': 2015,
#   'token_str': '##s',
#   'sequence': 'all humans are born free and equal in dignity and rights.'},
#  {'score': 0.016075611114501953,
#   'token': 2967,
#   'token_str': 'groups',
#   'sequence': 'all human groups are born free and equal in dignity and rights.'},
#  {'score': 0.013633023016154766,
#   'token': 2913,
#   'token_str': 'studies',
#   'sequence': 'all human studies are born free and equal in dignity and rights.'},
#  {'score': 0.01148589514195919,
#   'token': 3314,
#   'token_str': 'issues',
#   'sequence': 'all human issues are born free and equal in dignity and rights.'}]
